# %%
import numpy as np
import pandas as pd

#import pandas_profiling
import ydata_profiling
from ydata_profiling import ProfileReport
 
from collections import Counter

import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.probability import FreqDist
from nltk.lm import Vocabulary

import re

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
#import nltk
#nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/danil-
# [nltk_data]     pass123/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('russian'))

# %% [markdown]
# # Read

# %%
df_train = pd.read_json("dataset/train.json")

# %%
df_train.head(3)
# Out:
#           id                                               text  \
# 0  809436509  Извещение о проведении открытого конкурса в эл...
# 1  854885310  ТРЕБОВАНИЯ К СОДЕРЖАНИЮ ЗАЯВКИ участника запро...
# 2    4382157  Извещение о проведении электронного аукциона д...
#
#                               label  \
# 0  обеспечение исполнения контракта
# 1  обеспечение исполнения контракта
# 2  обеспечение исполнения контракта
#
#                                       extracted_part
# 0  {'text': ['Размер обеспечения исполнения контр...
# 1  {'text': ['Поставщик должен предоставить обесп...
# 2  {'text': ['Размер обеспечения исполнения контр...

# %%
def extracted_p_process(df_extracted_part,column):
    res = []
    for items in list(df_extracted_part[column]):
        if len(items)==1:
            res.append(items[0])
        else:
            raise Error("Only one fragment expected")
    return pd.Series(res)

# %%
df_extracted_part = pd.DataFrame.from_records(list(df_train['extracted_part']))
for c in df_extracted_part.columns:
    df_extracted_part[c] = extracted_p_process(df_extracted_part,c)

df_extracted_part.head(3)
# Out:
#                                                 text  answer_start  answer_end
# 0  Размер обеспечения исполнения контракта 6593.2...          1279        1343
# 1  Поставщик должен предоставить обеспечение испо...          1222        1318
# 2     Размер обеспечения исполнения контракта 10.00%          1297        1343

# %%
df = pd.concat([df_train,df_extracted_part],axis=1)
df = df.drop(['extracted_part'],axis=1)

df.columns = pd.Index(['id', 'text', 'label', 'text_output', 'answer_start', 'answer_end'])
df.head(5)
# Out:
#           id                                               text  \
# 0  809436509  Извещение о проведении открытого конкурса в эл...
# 1  854885310  ТРЕБОВАНИЯ К СОДЕРЖАНИЮ ЗАЯВКИ участника запро...
# 2    4382157  Извещение о проведении электронного аукциона д...
# 3  184555082  Извещение о проведении электронного аукциона д...
# 4  211645258  Извещение о проведении электронного аукциона д...
#
#                               label  \
# 0  обеспечение исполнения контракта
# 1  обеспечение исполнения контракта
# 2  обеспечение исполнения контракта
# 3  обеспечение исполнения контракта
# 4  обеспечение исполнения контракта
#
#                                          text_output  answer_start  answer_end
# 0  Размер обеспечения исполнения контракта 6593.2...          1279        1343
# 1  Поставщик должен предоставить обеспечение испо...          1222        1318
# 2     Размер обеспечения исполнения контракта 10.00%          1297        1343
# ...

# %%
# #profile = df.profile_report(title='Pandas Profiling Report', progress_bar=True)
# profile = ProfileReport(df,title="Profiling Report", progress_bar=True)

# profile.to_file("report.html")
# #profile.to_widgets()
# #profile

# %%
#df['answer_start'],df['answer_end'][]

# %% [markdown]
# # Preprocess

# %%
data,data_output = list(df['text']),list(df['text_output'])
#for text in data:
text = data[0]
words = word_tokenize(text)
#words,stop_words

# %%
other_word_dict = {"stopwords":dict(),"numbers":dict(),"symbols":dict(),"synonims":dict()}
word_dict = {"all_words":dict(),"output_words":dict(),"words_after_transform":dict()}

def collect(word):
    collect_stopwords(word)
    collect_numbers(word)
    collect_symbols(word)
    collect_words(word)

def collect_after_transform(word):
    collect_words_after_transform(word)
    
def collect_words(word):
    if word in word_dict["all_words"].keys():
        word_dict["all_words"][word]+=1
    else:
        word_dict["all_words"][word] = 1

def collect_output_words(word):
    if word in word_dict["output_words"].keys():
        word_dict["output_words"][word]+=1
    else:
        word_dict["output_words"][word] = 1
            
def collect_words_after_transform(word):
    if word in word_dict["words_after_transform"].keys():
        word_dict["words_after_transform"][word]+=1
    else:
        word_dict["words_after_transform"][word] = 1
            
    
def collect_stopwords(word):
    if word in stop_words:
        if word in other_word_dict["stopwords"].keys():
            other_word_dict["stopwords"][word]+=1
        else:
            other_word_dict["stopwords"][word] = 1
            
def collect_numbers(word):
    if any(char.isdigit() for char in word):
        if word in other_word_dict["numbers"].keys():
            other_word_dict["numbers"][word]+=1
        else:
            other_word_dict["numbers"][word] = 1

def collect_symbols(word):
    if (not any(char.isalpha() for char in word) and\
        not any(char.isdigit() for char in word)):
        if word in other_word_dict["symbols"].keys():
            other_word_dict["symbols"][word]+=1
        else:
            other_word_dict["symbols"][word] = 1
            
def collect_synonims():
    pass

# %%
tokens = ["<sw>",  #stopword
          "<sot>", #start of text
          "<eot>", #end of text
          "<bos>", #start of sentence
          "<eos>", #start of sentence
          "<num>", #number
          "<>"     #exclude word
          ]

def preprocess_word(word):
    word = word.lower()
    return word
    
def exclude_stopwords(word):
    if word in stop_words:
        return "<sw>"
    return word


def exclude_punctuation_signs(word):
    if word in "().,?/!@№":
        return "<>"
    return word
    pass

def exclude_digits(word):
    if any(char.isdigit() for char in word):
        words = re.split(r'([\d,\.,\,]+)', word)
        new_words = []
        for w in words:
            if w!='':
                if any(char.isdigit() for char in w):
                    new_words.append("<num>")
                else:
                    new_words.append(w)
        
        return new_words
    return [word]

# %%
def process_text(text):
    current_text_words = []
    word_position_list_sample = []
    past_text_len = 0
    
    for sentence in sent_tokenize(text):
        #current_text_words.append("<bos>")
        for w in word_tokenize(sentence):
            
            w_l = len(w) + 1
            left = past_text_len
            right = past_text_len + w_l
            
            past_text_len += w_l
            
            
            w = preprocess_word(w)
            collect(w)
            
            w = exclude_stopwords(w)
            w = exclude_punctuation_signs(w)
            
            if w == "<>":
                continue
            
            w = exclude_digits(w)
            for w1 in w:
                word_position_list_sample.append([left,right])
                collect_after_transform(w1)
                #text_all_words_list.append(w)
                current_text_words.append(w1)
        #current_text_words.append("<eos>")
    return current_text_words, word_position_list_sample

def process_texts_list(texts):
    text_list_of_words = []
    text_all_words_list = []
    word_position_list = []
    for text in texts:
        current_text_words, word_position_list_sample = process_text(text)
        
        text_list_of_words.append(current_text_words)
        word_position_list.append(word_position_list_sample)
        for w in current_text_words:
            text_all_words_list.append(w)
            
    return text_list_of_words, text_all_words_list, word_position_list

# %%
text_list_of_words, text_all_words_list, word_position_list = process_texts_list(list(df.text))

# %%
output_text_list_of_words, output_text_all_words_list, output_word_position_list = process_texts_list(list(df.text_output))

# %%
output_text_list_of_words[0]
# Out:
# ['размер',
#  'обеспечения',
#  'исполнения',
#  'контракта',
#  '<num>',
#  'российский',
#  'рубль']

# %%
def search_fragment_index(text,left,right):
    res = []

    for i,[l,r] in enumerate(text):

        if (l> left) and len(res)==0:
            #print("start",i,l,r)
            res.append(i)

        if (l> left) and (l > right):
            #print("end",i,l,r)
            res.append(i)
            break
    return res

# %%
def get_seq_start(seq,true_seq):
    #seq = text_list_of_words[0][res[0]-5:res[1]+20]
    #true_seq = output_text_list_of_words[0]
    res = []
    res_conf = []
    
    for i,w in enumerate(seq):
        if w == true_seq[0]:
            start = i
            
            conf,end_pos = get_seq_end(i,seq[i:],true_seq)
            if conf>0.5:
                res.append([start,start+end_pos])
                res_conf.append(conf)
    
    if len(res_conf)==0:
        return [res,res_conf],res
    return [res,res_conf],res[np.argmax(res_conf)]
    
                
        
def get_seq_end(start,seq,true_seq):
    #seq = text_list_of_words[0][r1[0]+res[0]-5:right]
    #true_seq = output_text_list_of_words[0]
    l = len(true_seq)
    right = l

    val = 0
    for i,(w1,w2) in enumerate(zip(seq[:right],
                             true_seq)):
        if w1==w2:
            val += 1
    
    return val/l,right

    

#print(r1[0]+res[0]-5,right,val/l)

# %%
def get_correct_fragment_positon(lengh_list,text,text_fragment,true_start,true_end):
    #lengh_list = word_position_list[0]
    #text = word_position_list[0]
    #text_fragment = output_text_list_of_words[0]
    #true_start = df['answer_start'][0]
    #true_end = df['answer_end'][0]
    
    res = search_fragment_index(lengh_list,true_start,true_end)
    start,end = res[0],res[1]
    res1,res_out = get_seq_start(text[start-5:end+20],text_fragment)
    
    if len(res1[0])==0:
    #if len(res1[0])>1 or len(res1[0])==0:
        print("res",res1);print("full text",text);print("text",text[start-5:end+20]);print("output",text_fragment)
        
    start,end = res_out[0]+res[0]-5,res_out[1]+res[0]-5
    
    return start,end

# %%
def extract_word_position_from_texts(word_position_list,text_list_of_words,output_text_list_of_words,df):    
    counter = 0
    words_index = []
    for pos,text,text_fragment,s,e in zip(word_position_list,text_list_of_words,output_text_list_of_words,list(df.answer_start),list(df.answer_end)):
        if s==0:
            words_index.append([0,0])
            continue
        start,end = get_correct_fragment_positon(pos,text,text_fragment,s,e)
        words_index.append([start,end])

        counter += 1
    return words_index

# %%
words_index[0]
# Out:
# [173, 180]

# %%
output_text_list_of_words[0]
# Out:
# ['размер',
#  'обеспечения',
#  'исполнения',
#  'контракта',
#  '<num>',
#  'российский',
#  'рубль']

# %%
text_list_of_words[0][words_index[0][0]:words_index[0][1]]
# Out:
# ['размер',
#  'обеспечения',
#  'исполнения',
#  'контракта',
#  '<num>',
#  'российский',
#  'рубль']

# %%
text_list_of_words[0][167:174]
# Out:
# ['исполнения',
#  'контракта',
#  'требуется',
#  'обеспечение',
#  'исполнения',
#  'контракта',
#  'размер']

# %% [markdown]
# -----------------------------------------------------

# %%
df['text'][0][1278:1343]
# Out:
# ' Размер обеспечения исполнения контракта 6593.25 Российский рубль'

# %% [markdown]
# # EDA

# %%
df.isna().sum()
# Out:
# id              0
# text            0
# label           0
# text_output     0
# answer_start    0
# answer_end      0
# dtype: int64

# %%
df['label'].unique()
# Out:
# array(['обеспечение исполнения контракта',
#        'обеспечение гарантийных обязательств'], dtype=object)

# %%
((df.answer_end - df.answer_start)<0).sum()
# Out:
# 0

# %% [markdown]
# ## Lenght stat

# %%
sourse_text_length = [len(item.split(' ')) for item in df['text'] ]
sourse_text_length = np.array(sourse_text_length)
output_text_length = [len(item.split(' ')) for item in df['text_output'] ]
output_text_length = np.array(output_text_length)

# %%
u,f = np.unique(sourse_text_length,return_counts = True)

u1,f1 = np.unique(output_text_length,return_counts = True)
plt.plot(u,f)
plt.show()
plt.plot(u1,f1)
plt.show()

# %%
idx = np.arange(len(sourse_text_length))
plt.plot(idx,sourse_text_length)
plt.plot(idx,output_text_length)
plt.show()
plt.hist(x = sourse_text_length,bins=idx)
plt.hist(x = output_text_length, bins=idx)
plt.show()

# %%
sourse_text_length.min(),sourse_text_length.max()

# %%
(output_text_length==1).sum(), (output_text_length>1).sum()

# %% [markdown]
# ## Term Frequency Analysis

# %%
df.info()

# %%
df.text_output
df.text

# %%
all_w_freq = FreqDist(word.lower() for word in text_all_words_list)
all_w_freq

# %%
mostCommon = Counter(text_all_words_list).most_common(40)
mostCommon

# %% [markdown]
# ## Stopwords/numbers and other

# %%
#pd.DataFrame.from_records(other_word_dict["stopwords"])
['stopwords', 'numbers', 'symbols', 'synonims']

df_sw = pd.DataFrame.from_dict(other_word_dict["symbols"], orient='index',columns = ["freq"])
df_sw = df_sw.reset_index()
df_sw = df_sw.sort_values(by=['freq'],ascending = False)

df_sw.head(4),df_sw.tail(4)
# Out:
# (  index   freq
#  1     ,  33480
#  3     .  20579
#  2     )  10283
#  0     (   9598,
#                                                   index  freq
#  183  ______________________________________________...     1
#  179  ______________________/_______________________...     1
#  177                        _____________________/_____     1
#  306  ______________________________________________...     1)

# %%
no_word_stat = {"stop_words":[],"numbers":[]}
for text in text_list_of_words:
    sw_counter = 0
    n_counter = 0
    for w in text:
        
        if w == "<sw>":
            sw_counter += 1
        if w == "<num>":
            n_counter += 1
    no_word_stat["stop_words"].append(sw_counter/len(text))
    no_word_stat["numbers"].append(n_counter/len(text))
    
no_word_stat = pd.DataFrame.from_dict(no_word_stat, orient='columns')
print(no_word_stat)

no_word_stat.plot.box()
no_word_stat.describe()
# Out:
#       stop_words   numbers
# 0       0.164596  0.074534
# 1       0.127451  0.091503
# 2       0.117834  0.108280
# 3       0.129231  0.083077
# 4       0.112853  0.081505
# ...          ...       ...
# 1794    0.201705  0.045455
# 1795    0.075949  0.183544
# 1796    0.175758  0.018182
# 1797    0.126984  0.111111
# 1798    0.088608  0.132911
#
# [1799 rows x 2 columns]
#         stop_words      numbers
# count  1799.000000  1799.000000
# mean      0.148092     0.075523
# std       0.034325     0.035684
# min       0.021898     0.006472
# 25%       0.127219     0.052632
# 50%       0.148256     0.069444
# 75%       0.171475     0.087227
# max       0.246057     0.370518

# %% [markdown]
# ## Most used words in target

# %%
word_dict.keys()
# Out:
# dict_keys(['all_words', 'output_words', 'words_after_transform'])

# %%
text_output_freq = {"words":[],"freq":[]}
for text in df.text_output:
    for w in word_tokenize(text):
        w = preprocess_word(w)
        collect_output_words(w)

# %%
df_ow = pd.DataFrame.from_dict(word_dict['output_words'], orient='index',columns = ["freq"])
df_ow = df_ow.reset_index()
df_ow = df_ow.sort_values(by=['freq'],ascending = False)

# %%
df_aw = pd.DataFrame.from_dict(word_dict['all_words'], orient='index',columns = ["freq"]).reset_index().sort_values(by=['freq'],ascending = False)

# %%
print(df_ow.head(10),df_ow.tail(10))
# Out:
#           index  freq
# 14            %  1141
# 3     контракта  1056
# 2    исполнения  1046
# 23            )  1036
# 21            (  1034
# 1   обеспечения  1003
# 0        размер   960
# 16         цены   938
# 59     договора   875
# 15           от   797           index  freq
# 599          95     1
# 600      266,08     1
# 601   денежного     1
# 602      456,06     1
# 604       70409     1
# 605          63     1
# 606       среди     1
# 607         мсп     1
# 610         826     1
# 1158      27450     1

# %%
df_ow[df_ow['freq']>50].freq.plot.bar()

# %%
df_ow[df_ow['freq']>200]
# Out:
#               index  freq
# 14                %  1141
# 3         контракта  1056
# 2        исполнения  1046
# 23                )  1036
# 21                (  1034
# 1       обеспечения  1003
# 0            размер   960
# 16             цены   938
# 59         договора   875
# 15               от   797
# 36        начальной   680
# 37     максимальной   679
# 11                в   619
# 90     обязательств   542
# 17                .   529
# 89      гарантийных   526
# 20                5   521
# 10      обеспечение   520
# 12          размере   453
# 31       составляет   423
# 25                ,   398
# 6             рубль   258
# 5        российский   258
# 55                :   232
# 19  устанавливается   209

# %%
for w,f in zip(df_ow['index'],df_ow['freq']):
    freq_output = f
    freq_all = list(df_aw[df_aw['index'] == w]['freq'])[0]
    
    
    
    doc_freq = 0
    if (freq_output - freq_all)>=0:
        doc_freq = 1
    elif (freq_output - freq_all)<0:
        doc_freq =2
    freq_output = freq_output/df_ow['freq'].sum()
    freq_all = freq_all/df_aw['freq'].sum()
    
    doc_freq = np.log(2/doc_freq)
    
    df_ow[df_ow['index']==w]['tf idf'] = freq_output*doc_freq
    df_aw[df_aw['index'] == w]['tf idf'] = freq_all*doc_freq
# Out:
# /tmp/ipykernel_12729/2113453265.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ow[df_ow['index']==w]['tf idf'] = freq_output*doc_freq
# /tmp/ipykernel_12729/2113453265.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aw[df_aw['index'] == w]['tf idf'] = freq_all*doc_freq
# /tmp/ipykernel_12729/2113453265.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_ow
# Out:
#            index  freq
# 14             %  1141
# 3      контракта  1056
# 2     исполнения  1046
# 23             )  1036
# 21             (  1034
# ...          ...   ...
# 605           63     1
# 606        среди     1
# 607          мсп     1
# 610          826     1
# 1158       27450     1
#
# [1159 rows x 2 columns]

# %%
# Out:
# 0.6931471805599453

# %%
i = 1
#df_aw[df_aw['index'] == df_ow['index'][0]]['freq'] - df_ow['freq'][0]
# Out:
# 106    1309
# Name: freq, dtype: int64

# %%
word_dict['all_words']
# Out:
# {'извещение': 854,
#  'о': 4530,
#  'проведении': 1178,
#  'открытого': 117,
#  'конкурса': 120,
#  'в': 18157,
#  'электронной': 1482,
#  'форме': 1471,
#  'для': 2634,
#  'закупки': 4893,
#  '№0328300032822000806': 1,
#  'общая': 584,
#  'информация': 1538,
#  'номер': 2238,
#  'извещения': 721,
#  '0328300032822000806': 1,
#  'наименование': 1579,
#  'объекта': 703,
#  'поставка': 385,
#  'продуктов': 172,
#  'питания': 175,
#  'способ': 1130,
#  'определения': 389,
#  'поставщика': 836,
#  '(': 9598,
#  'подрядчика': 451,
#  ',': 33480,
#  'исполнителя': 346,
#  ')': 10283,
#  'открытый': 89,
#  'конкурс': 47,
#  'бль': 2,
#  'порядок': 1390,
#  'внесения': 527,
#  'денежных': 1710,
#  'средств': 1918,
#  'качестве': 608,
#  'обеспечения': 6883,
#  'заявки': 1404,
#  'на': 7039,
#  'участие': 1080,
#  'закупке': 1425,
#  'а': 780,
#  'также': 515,
#  'условия': 395,
#  'гарантии': 3116,
#  'обеспечение': 4664,
#  'может': 1010,
#  'предоставляться': 74,
#  'участником': 1710,
# ...
